# %% [markdown]
# ## Question 1: Down payment calculation program (15 Marks)
#
# You just started working and decide that you want to start saving to buy a house.  You are going to have to save for some time to make the down payment on a house.
# Write a program to calculate and return how many months it will take you to save up enough money for the down payment required. Given the following assumptions:
#
# 1. Name the cost of your dream home **total_cost**.
# 2. Assume your annual salary is **annual_salary**.
# 3. Name the percent of the cost needed for a down payment **percent_down_payment**. For simplicity, assume that percent_down_payment is 25%.
# 4. You are going to dedicate a certain percent of your salary each month to saving for the down payment. Name that **percent_savings**. This variable should be in decimal form (eg. 0.1 for 10%).
# 5. You will also invest the above savings with an annual return of r (in other words, at the end of each month, you receive **monthly_returns** = current_savings*(r/12) of investment returns back.
# Assume that your investments earn an annual return **r of  4%**. And to keep things simple, it will not be compounded.
#
# #### Task: Determine how long it takes for you to achieve the down payment needed, taking into consideration the total investment returns and monthly savings. Assume you are going to put all your monthly investment returns and monthly savings into your down payment.
#
# **You will want your main variables to be floats.**
# <br>Your program should ask the user to enter the following variables:
# <br>**1. The starting annual salary (annual_salary)**
# <br>**2. The percent of salary to be saved (percent_savings)**
# <br>**3. The cost of your dream home (total_cost)**
#
# Tips:
# - Retrieve user inputs with input(). For this problem set, you can assume that users will enter valid input (e.g. they won’t enter a string when you expect a number)
# - Be careful about values that represent annual amounts and those that represent monthly amounts.
#
# #### Test case:
# User inputs:
# - annual_salary = 50000
# - portion_saved = 0.5
# - total_cost = 350000

# %%
# user inputs
annual_salary = float(input('Enter your annual salary - $'))
percent_savings = float(input('Enter percentage of your salary to be saved as a decimal, e.g. 0.1 for 10% - '))
total_cost = float(input('Enter cost of your dream home - $'))

# known
percent_down_payment = 0.25
down_payment = total_cost*percent_down_payment
monthly_salary = annual_salary/12
monthly_savings = monthly_salary*percent_savings
r = 0.04  # simple interest
current_savings = 0
months = 0


while current_savings < down_payment:

    investments = (current_savings*r)/12
    current_savings += investments
    current_savings += monthly_savings
    months += 1
    
else:
    print("It will take", months, "months to save up for the down payment at this rate")
# Out:
# Enter your annual salary - $50000
# Enter percentage of your salary to be saved as a decimal, e.g. 0.1 for 10% - 0.5
# Enter cost of your dream home - $350000
# It will take 40 months to save up for the down payment at this rate

# %% [markdown]
# ## Question 2 – Decision Tree Simulation - (15 Marks)
#
# This program will simulate how a decision tree behaves. A decision tree starts with a single decision, and then branches out to more decision paths. Write a function with 3 arguments that output the medical diagnosis that corresponds to the described conditions below.
#
# There are total of 3 conditions (arguments) :
# - fever, stuffy nose, rash
# - make the arguments **boolean** types
#
# The conditions and diagnosis are:
# ##### Condition --- Diagnosis
# - No fever, no stuffy nose. --- Hypochondriac
# - No fever, stuffy nose. --- Head cold
# - Fever, rash. --- Measles
# - Fever, no rash. --- Flu
#
# Hint: You may draw a tree diagram that branches out conditions and their diagnosis, to help you visualize the logic. An example of tree diagram:
#
# #### Test Case: all 4 cases, individually

# %%
# test condition - no fever, no stuffy nose - hypochondriac
fever = input("Do you have a fever (y/n): ")

if fever == "n":
    stuffynose = input("Do you have a stuffy nose (y/n): ")
    if stuffynose == "y":
        print("Diagnosis: Head cold")
    else:
        print("Diagnosis: Hypochondriac")
        
else:
    rash = input("Do you have a rash (y/n): ")
    if rash == "y":
        print("Diagnosis: Measles")
    else:
        print("Diagnosis: Flu")

print()

# test condition - no fever, stuffy nose - head cold
fever = input("Do you have a fever (y/n): ")

if fever == "n":
    stuffynose = input("Do you have a stuffy nose (y/n): ")
    if stuffynose == "y":
        print("Diagnosis: Head cold")
    else:
        print("Diagnosis: Hypochondriac")
        
else:
    rash = input("Do you have a rash (y/n): ")
    if rash == "y":
        print("Diagnosis: Measles")
    else:
        print("Diagnosis: Flu")

print()

# test condition - fever, rash - measles
fever = input("Do you have a fever (y/n): ")

if fever == "n":
    stuffynose = input("Do you have a stuffy nose (y/n): ")
    if stuffynose == "y":
        print("Diagnosis: Head cold")
    else:
        print("Diagnosis: Hypochondriac")
        
else:
    rash = input("Do you have a rash (y/n): ")
    if rash == "y":
        print("Diagnosis: Measles")
    else:
        print("Diagnosis: Flu")

print()

# test condition - fever, no rash - flu
fever = input("Do you have a fever (y/n): ")

if fever == "n":
    stuffynose = input("Do you have a stuffy nose (y/n): ")
    if stuffynose == "y":
        print("Diagnosis: Head cold")
    else:
        print("Diagnosis: Hypochondriac")
        
else:
    rash = input("Do you have a rash (y/n): ")
    if rash == "y":
        print("Diagnosis: Measles")
    else:
        print("Diagnosis: Flu")
# Out:
# Do you have a fever (y/n): n
# Do you have a stuffy nose (y/n): n
# Diagnosis: Hypochondriac
#
# Do you have a fever (y/n): n
# Do you have a stuffy nose (y/n): y
# Diagnosis: Head cold
#
# Do you have a fever (y/n): y
# Do you have a rash (y/n): y
# Diagnosis: Measles
#
# Do you have a fever (y/n): y
# Do you have a rash (y/n): n
# Diagnosis: Flu

# %% [markdown]
# ## Question 3 – Looping and filtering a selected list - (15 Marks)
#
# Declare 3 lists:
# <br>**list1 = [1,2,3,4,5]**
# <br>**list2 =  [11,12,13,14,15]**
# <br>**list3 = [21,22,23,24,25]**
#
# #### Get user input on which list he wants to choose, by using a string input.
# #### Eg. If user inputs list1, assign it as selected_list and use it for operations below.
#
# According to the choice of the user, perform below 2 operations on the selected_list:
#
# A)  Print all **even indexed** elements of selected_list using for loop   (ie. selected_list[0], selected_list[2], selected_list[4]...)
#
# If list3 is chosen:
#
# SAMPLE OUTPUT:
# 21
# 23
# 25
#
# B) Filter and print the **even numbers** of selected_list using lambda function.
# SAMPLE OUTPUT:
# [22,24]
#
# #### Test Case
# All 3 lists, individually

# %%
list1 = [1,2,3,4,5]
list2 = [11,12,13,14,15]
list3 = [21,22,23,24,25]

print("Choose a list to work on")
print("list1 = [1,2,3,4,5]")
print("list2 = [11,12,13,14,15]")
print("list3 = [21,22,23,24,25]")
print()

# test case list 1
userinput = str(input("Enter list1, list2 or list3: "))

if userinput == "list1":
    selected_list = [1,2,3,4,5]
      
elif userinput == "list2":
    selected_list = [11,12,13,14,15]

elif userinput == "list3":
    selected_list = [21,22,23,24,25]
    
print()

# for loop
print("(A) Even indexed elements in selected list:")
even_index = len(selected_list)
for i in range(0, even_index, 2):
    print(selected_list[i], end=" ")
    
print()

# lambda
print("(B) Even numbers in selected list:")
even_numbers = list(filter(lambda x: x%2 ==0, selected_list))
print(even_numbers)

print()

# test case list 2
userinput = str(input("Enter list1, list2 or list3: "))

if userinput == "list1":
    selected_list = [1,2,3,4,5]
      
elif userinput == "list2":
    selected_list = [11,12,13,14,15]

elif userinput == "list3":
    selected_list = [21,22,23,24,25]
    
print()

# for loop
print("(A) Even indexed elements in selected list:")
even_index = len(selected_list)
for i in range(0, even_index, 2):
    print(selected_list[i], end=" ")
    
print()

# lambda
print("(B) Even numbers in selected list:")
even_numbers = list(filter(lambda x: x%2 ==0, selected_list))
print(even_numbers)

print()

# test case list 3
userinput = str(input("Enter list1, list2 or list3: "))

if userinput == "list1":
    selected_list = [1,2,3,4,5]
      
elif userinput == "list2":
    selected_list = [11,12,13,14,15]

elif userinput == "list3":
    selected_list = [21,22,23,24,25]
    
print()

# for loop
print("(A) Even indexed elements in selected list:")
even_index = len(selected_list)
for i in range(0, even_index, 2):
    print(selected_list[i], end=" ")
    
print()

# lambda
print("(B) Even numbers in selected list:")
even_numbers = list(filter(lambda x: x%2 ==0, selected_list))
print(even_numbers)
# Out:
# Choose a list to work on
# list1 = [1,2,3,4,5]
# list2 = [11,12,13,14,15]
# list3 = [21,22,23,24,25]
#
# Enter list1, list2 or list3: list1
#
# (A) Even indexed elements in selected list:
# 1 3 5
# (B) Even numbers in selected list:
# [2, 4]
#
# Enter list1, list2 or list3: list2
#
# (A) Even indexed elements in selected list:
# 11 13 15
# (B) Even numbers in selected list:
# [12, 14]
#
# Enter list1, list2 or list3: list3
#
# (A) Even indexed elements in selected list:
# 21 23 25
# (B) Even numbers in selected list:
# [22, 24]

# %% [markdown]
# ## Question 4 - Vehicles and Motorbikes (15 Marks)
#
# A) Create a class Vehicle with the following attributes:
# 	Init constructor with 2 parameters where there is engine (default is “A”) and tires (default is 4)
# 	Method called drive( where it prints “I am being driven!”
#
# #### Test Case
# Create a Vehicle object v1 and call the drive method.
#
#
# B) Create a child class Motorbike of parent class Vehicle with following attributes:
# 	Override the Vehicle init constructor with 3 parameters where now there is name, engine, tires (default is 2)
# 	Method called seats which prints “I can seat 2 people!”
# 	Special method for add which uses the + operator, resulting in using 2 people’s names to  print: “Person1: (name) , Person2: (name)”
#
# #### Test Case
# Create 2 Motorbike objects, v2, v3.
# v2 has engine called “B” and name “Mike”.
# v3 has engine called “C” and name “Peter”
# Call v2’s drive method and seats method.
# Use special method of add to call the + operator on v2 and v3, which prints “Person 1: Mike, Person2: Peter

# %%
class Vehicle:
    def __init__(self, engine="A", tires="4"):
        self.engine = engine
        self.tires = tires
        
    def drive(self):
        print("I am being driven!")

        
# test case Vehicle object v1 and call the drive method
print("test case v1")
v1 = Vehicle()
v1.drive()

print()
class Motorbike(Vehicle):
    def __init__(self, name, engine, tires="2"):
        self.name = name
        self.engine = engine
        self.tires = tires
        
    def seats(self):
        print("I can seat 2 people!")
        
# test case 2 motorbike objects v2, v3
print("test case v2, v3")
v2 = Motorbike("Mike", "B")
v3 = Motorbike("Peter", "C")

v2.drive()
v2.seats()

class Motorbike(Vehicle):
    def __add__(self, other):
        return Motorbike(self.name+other.name)
# Out:
# test case v1
# I am being driven!
#
# test case v2, v3
# I am being driven!
# I can seat 2 people!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-e6bb0061086c> in <module>
#      35         return Motorbike(self.name+other.name)
#      36
# ---> 37 print(v2+v3)
#      38
#      39
#
# TypeError: unsupported operand type(s) for +: 'Motorbike' and 'Motorbike'

# %% [markdown]
# ## BONUS Question - 4 marks (Optional, if correct will be added to your overall score)
# Create a decorator that prints “this is a sedan” first and then the original function.
# Create a child class Sedan of parent class Vehicle. Define method seats to print “I am a seat”.
# Wrap the decorator around the method seats, and call the newly decorated seats method for an object.
#
# Test case
# v4 = Sedan()
# v4.seats()
#
# Output:
# “this is a sedan”
# “I am a seat”

# %%
def my_decorator(func):
    
    def wrapper(x):
        print("This is a sedan")
        func(x)
        
    
    return wrapper

@my_decorator
def
